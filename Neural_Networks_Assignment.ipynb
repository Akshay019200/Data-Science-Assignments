# %%
from google.colab import files

ploaded= files.upload()
# Out:
#      <input type="file" id="files-1461c9b4-dce4-463a-a510-7cfec380cdd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1461c9b4-dce4-463a-a510-7cfec380cdd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **1. Data Exploration and Preprocessing**

# %%
# Loading the dataset and checking the size

df= pd.read_csv("Alphabets_data.csv")
df.shape
# Out:
# (20000, 17)

# %%
# Checking for unique values

df["letter"].value_counts()
# Out:
# letter
# U    813
# D    805
# P    803
# T    796
# M    792
# A    789
# X    787
# Y    786
# N    783
# Q    783
# F    775
# G    773
# E    768
# B    766
# V    764
# L    761
# R    758
# I    755
# O    753
# W    752
# S    748
# J    747
# K    739
# C    736
# H    734
# Z    734
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
# Checking for duplicates

df[df.duplicated()].shape
# Out:
# (1332, 17)

# %%
# They are not exactly same so we will not drop them

df[df.duplicated()]
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 627        I     3     7      4       5      2     7     7      0      7
# 724        L     3     6      3       4      1     1     0      6      6
# 730        I     1     9      0       6      0     7     7      4      4
# 910        X     5    11      6       8      2     7     7      5      4
# 943        O     2     3      2       1      1     8     7      6      4
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19948      T     4     5      4       4      2     6    11      2      7
# 19950      O     4     5      5       4      3     7     7      8      5
# 19975      E     1     0      1       0      0     5     8      5      7
# 19987      L     3     7      3       5      1     0     1      6      6
# 19998      S     2     3      4       2      1     8     7      2      6
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...

# %%
# Checking the data type

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
# Basic statistics

df.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# ...

# %%
# Histogram

for i in df.columns:
  if df[i].dtype== "int64":
    plt.figure(figsize=(8,6))
    sns.histplot(df[i], kde=True)
    plt.title(f"Histogram of {i}")
    plt.xlabel(i)
    plt.ylabel("Frequency")
    plt.show()

# %%
# Boxplot

for i in df.columns:
  if df[i].dtype== "int64":
    plt.figure(figsize=(8,6))
    sns.boxplot(df[i])
    plt.title(f"Histogram of {i}")
    plt.show()

# %% [markdown]
# # **2. Model Implementation**

# %%
# Assigning x and y variables
x= df.drop("letter", axis=1)
x.head()
# Out:
#    xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  x2ybar  \
# 0     2     8      3       5      1     8    13      0      6      6      10
# 1     5    12      3       7      2    10     5      5      4     13       3
# 2     4    11      6       8      6    10     6      2      6     10       3
# 3     7    11      6       6      3     5     9      4      6      4       4
# 4     2     1      3       1      1     8     6      6      6      6       5
#
#    xy2bar  xedge  xedgey  yedge  yedgex
# 0       8      0       8      0       8
# 1       9      2       8      4      10
# 2       7      3       7      3       9
# 3      10      6      10      2       8
# 4       9      1       7      5      10

# %%
y= df["letter"]

# %%
# Standardization

from sklearn.preprocessing import StandardScaler

ss= StandardScaler()
ss_x= ss.fit_transform(x)
ss_x= pd.DataFrame(ss_x)
ss_x.columns= list(x)
ss_x.head()
# Out:
#        xbox      ybox     width    height     onpix      xbar      ybar  \
# 0 -1.057698  0.291877 -1.053277 -0.164704 -1.144013  0.544130  2.365097
# 1  0.510385  1.502358 -1.053277  0.719730 -0.687476  1.531305 -1.075326
# 2 -0.012309  1.199738  0.435910  1.161947  1.138672  1.531305 -0.645273
# 3  1.555774  1.199738  0.435910  0.277513 -0.230939 -0.936631  0.644886
# 4 -1.057698 -1.826464 -1.053277 -1.933571 -1.144013  0.544130 -0.645273
#
#       x2bar     y2bar     xybar    x2ybar    xy2bar     xedge    xedgey  \
# 0 -1.714360  0.344994 -0.917071  1.347774  0.034125 -1.305948 -0.219082
# 1  0.137561 -0.495072  1.895968 -1.312807  0.514764 -0.448492 -0.219082
# 2 -0.973591  0.344994  0.690380 -1.312807 -0.446513 -0.019764 -0.865626
# 3 -0.232823  0.344994 -1.720796 -0.932724  0.995402  1.266419  1.074008
# 4  0.507945  0.344994 -0.917071 -0.552641  0.514764 -0.877220 -0.865626
#
#       yedge    yedgex
# 0 -1.438153  0.122911
# 1  0.120081  1.359441
# 2 -0.269477  0.741176
# ...

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.15.0'

# %%
# One-Hot encoding for y variables


from sklearn.preprocessing import LabelEncoder

# Encode categorical labels to numeric values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Convert labels to one-hot encoded format
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# %%
# Model fitting

ann= tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units= 16, activation= "relu"))
ann.add(tf.keras.layers.Dense(units= 25, activation= "relu"))
ann.add(tf.keras.layers.Dense(units=26, activation= "softmax"))

# %%
# Training the ANN

ann.compile(optimizer= "adam", loss= "categorical_crossentropy", metrics= ["accuracy"])

# %%
# Training the ANN on the Training set

history= ann.fit(ss_x, y_onehot, validation_split= 0.30, batch_size=100, epochs= 50)
# Out:
# Epoch 1/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0502 - loss: 3.2091 - val_accuracy: 0.2845 - val_loss: 2.5929
# Epoch 2/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3435 - loss: 2.3675 - val_accuracy: 0.4813 - val_loss: 1.8166
# Epoch 3/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5217 - loss: 1.6919 - val_accuracy: 0.5905 - val_loss: 1.4311
# Epoch 4/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6102 - loss: 1.3736 - val_accuracy: 0.6318 - val_loss: 1.2467
# Epoch 5/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6568 - loss: 1.2012 - val_accuracy: 0.6667 - val_loss: 1.1310
# Epoch 6/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6764 - loss: 1.0893 - val_accuracy: 0.6888 - val_loss: 1.0503
# Epoch 7/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7051 - loss: 1.0043 - val_accuracy: 0.7033 - val_loss: 0.9905
# Epoch 8/50
# ...

# %% [markdown]
# # **3. Hyperparameter Tuning**

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

class CustomKerasClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, units=32, activation='relu', optimizer='adam', epochs=50):
        self.units = units
        self.activation = activation
        self.optimizer = optimizer
        self.epochs = epochs
        self.model = None

    def fit(self, X, y):
        self.model = Sequential()
        self.model.add(Dense(units=self.units, activation=self.activation, input_shape=(X.shape[1],)))
        self.model.add(Dense(units=self.units//2, activation=self.activation))
        self.model.add(Dense(units=y.shape[1], activation='softmax'))
        self.model.compile(optimizer=self.optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
        self.model.fit(X, y, epochs=self.epochs, verbose=0)
        return self

    def predict(self, X):
        y_pred = self.model.predict(X)
        return y_pred.argmax(axis=1)

    def score(self, X, y):
        y_pred = self.predict(X)
        return accuracy_score(y.argmax(axis=1), y_pred)

# Define the hyperparameter grid with reduced combinations
param_grid = {
    'units': [16, 32],
    'activation': ['relu', 'tanh'],
    'optimizer': ['adam'],
    'epochs': [50, 100]
}

# Create the CustomKerasClassifier object
custom_keras_classifier = CustomKerasClassifier()

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=custom_keras_classifier, param_grid=param_grid, cv=5)

# Fit the model to the data
grid_search.fit(ss_x, y_onehot)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Print the best hyperparameters
print(best_params)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ...

# %%
# Model fitting with best parameter

ann= tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units= 16, activation= "relu"))
ann.add(tf.keras.layers.Dense(units= 32, activation= "relu"))
ann.add(tf.keras.layers.Dense(units=26, activation= "softmax"))

# %%
# Training the ANN with best parameter

ann.compile(optimizer= "adam", loss= "categorical_crossentropy", metrics= ["accuracy"])

# %%
# Training the ANN on the Training set with best parameter

history= ann.fit(ss_x, y_onehot, validation_split= 0.30, batch_size=100, epochs= 100)
# Out:
# Epoch 1/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1101 - loss: 3.1112 - val_accuracy: 0.3363 - val_loss: 2.3605
# Epoch 2/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4028 - loss: 2.1303 - val_accuracy: 0.5292 - val_loss: 1.6145
# Epoch 3/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5589 - loss: 1.5150 - val_accuracy: 0.6137 - val_loss: 1.3044
# Epoch 4/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6382 - loss: 1.2209 - val_accuracy: 0.6567 - val_loss: 1.1494
# Epoch 5/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6811 - loss: 1.0911 - val_accuracy: 0.6850 - val_loss: 1.0573
# Epoch 6/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7094 - loss: 0.9995 - val_accuracy: 0.7022 - val_loss: 0.9927
# Epoch 7/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7182 - loss: 0.9531 - val_accuracy: 0.7170 - val_loss: 0.9389
# Epoch 8/100
# ...

# %% [markdown]
# # **4. Evaluation**

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import tensorflow as tf

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(ss_x, y_onehot, test_size=0.2, random_state=42)

# Define and compile the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=16, activation="relu"),
    tf.keras.layers.Dense(units=32, activation="relu"),
    tf.keras.layers.Dense(units=26, activation="softmax")
])
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, validation_split=0.3, batch_size=100, epochs=100, verbose=0)

# Evaluate the model on the test set
y_pred = model.predict(x_test)

# Convert predictions from one-hot encoded format to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calculate evaluation metrics
accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='macro')
recall = recall_score(y_true_classes, y_pred_classes, average='macro')
f1 = f1_score(y_true_classes, y_pred_classes, average='macro')

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.8835
# Precision: 0.8850520580236475
# Recall: 0.8829856968519384
# F1-score: 0.8831665374108684

# %% [markdown]
# Before applying hyperparameter tuning, the model achieved an accuracy of 85.96% with a loss of 0.4636 on the training data, and an accuracy of 83.90% with a loss of 0.5144 on the validation data. After hyperparameter tuning, the model's performance improved significantly. It achieved an accuracy of 90.75% with a loss of 0.2994 on the training data, and an accuracy of 88.03% with a loss of 0.3945 on the validation data. This indicates a notable enhancement in model performance, with the test accuracy increasing from 84% to 88%, and the loss decreasing from 0.51 to 0.39.

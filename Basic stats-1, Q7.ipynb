# %%
import pandas as pd
import numpy as np
import statistics as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("E:\\download folder\\Q7.csv")
df.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
df.shape
# Out:
# (32, 4)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# SP            0
# WT            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   Points      32 non-null     float64
#  2   Score       32 non-null     float64
#  3   Weigh       32 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.1+ KB

# %%
np.std(df["Weigh"].round(2))
# Out:
# 1.758800638929836

# %%
np.mean(df["Points"])
# Out:
# 3.5965625

# %%
np.median(df["Points"])
# Out:
# 3.6950000000000003

# %%
stats.mode(df["Points"])
# Out:
# 3.92

# %%
np.std(df["Points"])
# Out:
# 0.5262580722361891

# %%
np.var(df["Points"])
# Out:
# 0.27694755859375003

# %%
range_points= np.max(df["Points"])-np.min(df["Points"])
range_points
# Out:
# 2.17

# %%
range_weigh= np.max(df["Weigh"])-np.min(df["Weigh"])
range_weigh
# Out:
# 8.399999999999999

# %%
range_score= np.max(df["Score"])-np.min(df["Score"])
range_score
# Out:
# 3.9110000000000005

# %%
stats.mode(df["Weigh"])
# Out:
# 17.02

# %%
sns.boxplot(df["Points"])
# Out:
# <Axes: ylabel='Points'>

# %%
sns.boxplot(df["Score"])
# Out:
# <Axes: ylabel='Score'>

# %%
sns.boxplot(df["Weigh"])
# Out:
# <Axes: ylabel='Weigh'>

# %%
sns.histplot(df["Points"], kde=True)
# Out:
# <Axes: xlabel='Points', ylabel='Count'>

# %%
sns.histplot(df["Score"], kde=True)
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %%
sns.histplot(df["Weigh"], kde=True)
# Out:
# <Axes: xlabel='Weigh', ylabel='Count'>

# %%
data= [108, 110, 123, 134, 135, 145, 167, 187, 199]
np.mean(data)
# Out:
# 145.33333333333334

# %%
df= pd.read_csv("E:\\download folder\\Q9_a.csv")
df.shape
# Out:
# (50, 3)

# %%
df.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
plt.scatter(df["speed"],df["dist"])
plt.figure(figsize=(15,10))
plt.show()
print("Skewness of Speed:", df["speed"].skew())
print("Kurtosis of Speed:",df["speed"].kurt())
# Out:
# Skewness of Speed: -0.11750986144663393
# Kurtosis of Speed: -0.5089944204057617

# %%
sns.histplot(df["speed"],kde=True)
print("Skewness of Speed:", df["speed"].skew())
print("Kurtosis of Speed:",df["speed"].kurt())
# Out:
# Skewness of Speed: -0.11750986144663393
# Kurtosis of Speed: -0.5089944204057617

# %%
sns.boxplot(df["speed"])
# Out:
# <Axes: ylabel='speed'>

# %%
sns.histplot(df["dist"], kde= True)
print("Skewness of Dist:", df["dist"].skew())
print("Kurtosis of Dist:",df["dist"].kurt())
# Out:
# Skewness of Dist: 0.8068949601674215
# Kurtosis of Dist: 0.4050525816795765

# %%
sns.boxplot(df["dist"])
# Out:
# <Axes: ylabel='dist'>

# %%
df= pd.read_csv("E:\\download folder\\Q9_b.csv")
df.head()
# Out:
#    Unnamed: 0          SP         WT
# 0           1  104.185353  28.762059
# 1           2  105.461264  30.466833
# 2           3  105.461264  30.193597
# 3           4  113.461264  30.632114
# 4           5  104.461264  29.889149

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# SP            0
# WT            0
# dtype: int64

# %%
df.shape
# Out:
# (81, 3)

# %%
plt.scatter(df["SP"],df["WT"])
plt.show()

print("Skewness of SP:", df["SP"].skew())
print("Kurtosis of SP:", df["SP"].kurt())
# Out:
# Skewness of SP: 1.6114501961773586
# Kurtosis of SP: 2.9773289437871835

# %%
sns.histplot(df["SP"], kde= True)
# Out:
# <Axes: xlabel='SP', ylabel='Count'>

# %%
sns.boxplot(df["SP"])
# Out:
# <Axes: ylabel='SP'>

# %%
sns.histplot(df["WT"], kde= True)

print("Skewness of WT:", df["WT"].skew())
print("Kurtosis of WT:", df["WT"].kurt())
# Out:
# Skewness of WT: -0.6147533255357768
# Kurtosis of WT: 0.9502914910300326

# %%
sns.boxplot(df["WT"])
# Out:
# <Axes: ylabel='WT'>

# %%
from scipy.stats import norm

sample_population= 2000
population= 3000000
sample_mean= 200
sample_std= 30
alpha= 0.04
zvalue= norm.ppf(1-alpha/2)

ub= sample_mean+ zvalue*(sample_std/(np.sqrt(2000)))
lb= sample_mean- zvalue*(sample_std/(np.sqrt(2000)))

print("I'm 96% confident that avg weight of the men lies between:", ub,lb)
# Out:
# I'm 96% confident that avg weight of the men lies between: 201.37769665186667 198.62230334813333

# %%
marks= [34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56]
np.mean(marks)
# Out:
# 41.0

# %%
np.median(marks)
# Out:
# 40.5

# %%
np.var(marks).round(2)
# Out:
# 24.11

# %%
np.std(marks).round(2)
# Out:
# 4.91

# %%
sns.histplot(marks)
# Out:
# <Axes: ylabel='Count'>

# %%
df= pd.read_csv("E:\\download folder\\Cars.csv")
df.shape
# Out:
# (81, 5)

# %%
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
sns.histplot(df["HP"], kde=True)
print("Skewness:", df["HP"].skew())
# Out:
# Skewness: 1.7162163889158817

# %%
sns.histplot(df["MPG"], kde=True)
print("Skewness:", df["MPG"].skew())
# Out:
# Skewness: -0.17794674747025727

# %%
sns.histplot(df["VOL"], kde=True)
print("Skewness:", df["VOL"].skew())
# Out:
# Skewness: -0.5901968186877561

# %%
sns.histplot(df["SP"], kde=True)
print("Skewness:", df["SP"].skew())
# Out:
# Skewness: 1.6114501961773586

# %%
sns.histplot(df["WT"], kde=True)
print("Skewness:", df["WT"].skew())
# Out:
# Skewness: -0.6147533255357768

# %%
df= pd.read_csv("E:\\download folder\\wc-at.csv")
df.shape
# Out:
# (109, 2)

# %%
df.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
sns.histplot(df["Waist"], kde=True)
print("Skewness:", df["Waist"].skew())
# Out:
# Skewness: 0.1340560824786468

# %%
sns.histplot(df["AT"], kde=True)
print("Skewness:", df["AT"].skew())
# Out:
# Skewness: 0.584869324127853

# %%
alpha= 0.4

zvalue= norm.ppf(1-alpha/2)
zvalue
# Out:
# 0.8416212335729143

# %%
from scipy import stats
alpha=0.01
t_value= stats.t.ppf(1-alpha/2, 24)
t_value.round(2)
# Out:
# 2.8

# %%
df= pd.read_csv("E:\\download folder\\Cars.csv")
df.shape
# Out:
# (81, 5)

# %%
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
mpg= df["MPG"]

favourable_outcome= ((20<mpg)&(mpg<50)).sum()
total_outcome= len(mpg)
probability = favourable_outcome/total_outcome
probability
# Out:
# 0.8518518518518519

# %%
from scipy.stats import t

sample_mean = 260
population_mean = 270
sample_std = 90
sample_size = 18

degrees_of_freedom = sample_size - 1
t_score = (sample_mean - population_mean) / (sample_std / (np.sqrt(18)))

# Find the probability
probability = t.cdf(t_score, df=degrees_of_freedom)
probability
# Out:
# 0.32167253567098364

# %%
from scipy.stats import norm

df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
df["MPG"]
# Out:
# 0     53.700681
# 1     50.013401
# 2     50.013401
# 3     45.696322
# 4     50.504232
#         ...
# 76    36.900000
# 77    19.197888
# 78    34.000000
# 79    19.833733
# 80    12.101263
# Name: MPG, Length: 81, dtype: float64

# %%
df= pd.read_csv("E:\\download folder\\Cars.csv")
df.shape
# Out:
# (81, 5)

# %%
df["MPG"]
# Out:
# 0     53.700681
# 1     50.013401
# 2     50.013401
# 3     45.696322
# 4     50.504232
#         ...
# 76    36.900000
# 77    19.197888
# 78    34.000000
# 79    19.833733
# 80    12.101263
# Name: MPG, Length: 81, dtype: float64

# %%
mpg= df["MPG"]

favorable_outcomes= (mpg> 38).sum()
total_outcomes= len(mpg)

probability= favorable_outcomes/total_outcomes
probability
# Out:
# 0.4074074074074074

# %%
favorable_outcomes= (mpg<40).sum()
total_outcomes= len(mpg)

probability= favorable_outcomes/total_outcomes
probability
# Out:
# 0.7530864197530864

# %%
favorable_outcomes= ((mpg>20) & (mpg<50))
favorable_outcomes=favorable_outcomes.sum()
total_outcomes= len(mpg)

probability= favorable_outcomes/total_outcomes
probability
# Out:
# 0.8518518518518519

# %%
df["MPG"].mean().round(2)
# Out:
# 34.42

# %%
round(df["MPG"].std(),2)
# Out:
# 9.13

# %%
from scipy.stats import norm

nd=norm(34.42, 9.13)
x1= 1- nd.cdf(37)
x1.round(2)
# Out:
# 0.39

# %%
x2= nd.cdf(40)
x2.round(2)
# Out:
# 0.73

# %%
x3= 1-nd.cdf(20)
x4= nd.cdf(50)
x5= x4-x3
x5
# Out:
# 0.01316016150187349
